# %% [markdown]
# # Word Embeddings

# %%
data_in = './data_in/'
data_out = './data_out/'
data_prefix = 'zapatistas'

# %%
OHCO = ['text_id', 'section_num', 'para_num', 'sent_num', 'token_num']
PARA = OHCO[:3] # Paragraphs
BAG = PARA

# %%
import pandas as pd
import numpy as np
from gensim.models import word2vec
from sklearn.manifold import TSNE
import plotly_express as px
# Out:
# c:\program files\python36\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
class W2VExplorer:
    
    w2v_min_count:int = 10
    w2v_workers:int = 4
    w2v_size:int = 246
    w2v_window:int = 2
    tsne_perplexity:int = 40
    tsne_n_components:int = 2
    tsne_init:str = 'pca'
    tsne_n_iter:int = 2500
    tsne_random_state:int = 23
        
    
    def __init__(self, tokens, bag):
        self.TOKENS:pd.DataFrame = tokens
        self.BAG = bag
        
    def generate_model(self):
        print("Bag:", self.BAG[-1])
        print('Getting DOCS')
        self._get_docs()
        print("Getting MODEL")
        self._get_model()
        print("Getting tSNE Coords")
        self._get_tsne_coords()
        print(u'\u2713')
        return self
        
    def _get_docs(self):
        self.DOCS = self.TOKENS.groupby(self.BAG)\
            .term_str.apply(lambda  x:  x.tolist())\
            .reset_index()['term_str'].tolist()
        
    def _get_model(self):
        self.model = word2vec.Word2Vec(self.DOCS, 
                                 vector_size = self.w2v_size, 
                                 window = self.w2v_window, 
                                 min_count = self.w2v_min_count, 
                                 workers = self.w2v_workers)

    def _get_tsne_coords(self):
        self.coords = pd.DataFrame(index=range(len(self.model.wv.key_to_index.values())))
        self.coords['label'] = [w for w in self.model.wv.index_to_key]
        self.coords['vector'] = self.coords['label'].apply(lambda x: self.model.wv.get_vector(x))
        self.tsne_model = TSNE(perplexity = 40, 
                               n_components = self.tsne_n_components, 
                               init = self.tsne_init, 
                               n_iter = self.tsne_n_iter, 
                               random_state = self.tsne_random_state)
        self.tsne_values = self.tsne_model.fit_transform(self.coords['vector'].tolist())
        self.coords['x'] = self.tsne_values[:,0]
        self.coords['y'] = self.tsne_values[:,1]
        
    def plot_tsne(self):
        px.scatter(self.coords, 'x', 'y', text='label', height=1000)\
            .update_traces(mode='text').show()
        
    def complete_analogy(self, A, B, C, n=2):
        try:
            cols = ['term', 'sim']
            return pd.DataFrame(self.model.wv.most_similar(positive=[B, C], negative=[A])[0:n], columns=cols)
        except KeyError as e:
            print('Error:', e)
            return None

    def get_most_similar(self, positive, negative=None):
        return pd.DataFrame(self.model.wv.most_similar(positive, negative), columns=['term', 'sim'])

# %%
TOKENS = pd.read_csv('{}/{}-TOKEN.csv'.format(data_in, data_prefix)).set_index(OHCO)
LIB = pd.read_csv('{}/{}-LIB.csv'.format(data_in, data_prefix)).set_index('text_id')

# %%
TOKENS = TOKENS[~TOKENS.pos.str.match(r'NNPS?')]

# %%
model = W2VExplorer(TOKENS, BAG)
model.w2v_min_count = 60
model.generate_model()
# Out:
# Bag: para_num
# Getting DOCS
# Getting MODEL
# Getting tSNE Coords
# ✓

# %%
model.plot_tsne()
# Out:
# <div>                            <div id="90c82722-08d2-42b9-b545-113b26fbbaae" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90c82722-08d2-42b9-b545-113b26fbbaae")) {                    Plotly.newPlot(                        "90c82722-08d2-42b9-b545-113b26fbbaae",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<br>label=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "text", "name": "", "orientation": "v", "showlegend": false, "text": ["the", "of", "to", "and", "that", "we", "in", "a", "is", "for", "they", "are", "our", "it", "have", "you", "not", null, "with", "be", "this", "will", "us", "people", "as", "i", "or", "from", "but", "there", "who", "what", "was", "on", "all", "their", "by", "if", "government", "them", "he", "because", "no", "one", "were", "do", "has", "so", "at", "an", "when", "say", "those", "would", "other", "its", "can", "about", "want", "now", "out", "dont", "only", "up", "which", "like", "your", "these", "political", "going", "struggle", "been", "had", "then", "women", "know", "country", "how", "any", "more", "just", "war", "peace", "many", "well", "some", "take", "military", "me", "said", "national", "should", "his", "dialogue", "way", "also", "democracy", "without", "1994", "very", "justice", "land", "mountains", "here", "first", "work", "companeros", "see", "come", "right", "go", "time", "brothers", "men", "federal", "freedom", "same", "demands", "even", "against", "why", "did", "make", "arms", "think", "could", "another", "indigenous", "communities", "already", "troops", "things", "years", "ask", "order", "good", "armed", "where", "being", "give", "get", "speak", "into", "yes", "state", "world", "peoples", "over", "than", "understand", "nothing", "respect", "truth", "tell", "death", "de", "my", "press", "campesinos", "through", "forces", "again", "must", "came", "until", "dignity", "still", "sisters", "since", "something", "everything", "says", "governments", "demand", "does", "cg", "let", "him", "part", "she", "themselves", "before", "made", "true", "new", "hope", "words", "example", "doesnt", "power", "case", "group", "am", "day", "need", "own", "children", "process", "continue", "anything", "long", "life", "didnt", "always", "mexican", "dead", "live", "weapons", "die", "change", "put", "end", "revolutionary", "democratic", "different", "following", "ourselves", "cant", "after", "force", "much", "civilian", "society", "law", "possible", "place", "question", "two", "necessary", "problems", "most", "workers", "civil", "movement", "told", "cannot", "q", "population", "asked", "ones", "organizations", "never", "support", "during", "others", "saw", "everyone", "among", "means", "party"], "type": "scatter", "x": [15.474106788635254, 15.488968849182129, -7.1514482498168945, 14.007546424865723, -11.571150779724121, -14.946664810180664, 14.460171699523926, 7.073068618774414, -4.679040908813477, 11.760706901550293, -13.871857643127441, -11.676462173461914, 11.410797119140625, -13.013190269470215, -13.345099449157715, -15.043593406677246, -12.274465560913086, 14.889716148376465, 10.012408256530762, -3.876375436782837, -2.8309013843536377, 2.0228452682495117, -9.715197563171387, 11.569899559020996, 1.9788247346878052, -15.241868019104004, 3.048901319503784, 13.795693397521973, -11.770903587341309, -9.576592445373535, 6.033764362335205, -14.572068214416504, -6.208555221557617, 10.220786094665527, 12.207399368286133, 12.700830459594727, 13.464967727661133, -13.750139236450195, 13.795034408569336, -10.3601655960083, -5.13872766494751, -11.681924819946289, -9.362446784973145, 7.108352184295654, -6.1487531661987305, -15.450843811035156, -0.896674633026123, -11.1194429397583, 5.783937454223633, 8.066797256469727, - ...

# %%
model.complete_analogy('men', 'women', 'government', 5)
# Out:
#           term       sim
# 0           by  0.987886
# 1      federal  0.986797
# 2    political  0.983968
# 3  governments  0.983539
# 4         from  0.981715

# %%
model.get_most_similar('indigenous')
# Out:
#           term       sim
# 0   campesinos  0.998468
# 1      workers  0.998367
# 2      against  0.998051
# 3       demand  0.997755
# 4       forces  0.997585
# 5  communities  0.997463
# 6      mexican  0.997413
# 7       troops  0.997192
# 8         land  0.997171
# 9        which  0.996960

# %%
model.get_most_similar('democratic')
# Out:
#         term       sim
# 0      party  0.998872
# 1   movement  0.998820
# 2      among  0.998817
# 3        new  0.998804
# 4        law  0.998769
# 5      force  0.998714
# 6     during  0.998675
# 7  different  0.998598
# 8      power  0.998575
# 9      group  0.998508

# %%
model.complete_analogy('brothers', 'sisters', 'revolutionary', 5)
# Out:
#          term       sim
# 0       armed  0.971952
# 1  democratic  0.971115
# 2      during  0.970991
# 3       words  0.970938
# 4        same  0.970927
